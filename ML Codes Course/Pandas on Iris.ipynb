# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import data from URL

# %%
url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data'
iris = pd.read_csv(url)

iris.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
iris.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width'], dtype='object')

# %% [markdown]
# Setting column names

# %%
iris.columns =  ['sepal_length','sepal_width', 'petal_length', 'petal_width', 'class']
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width        class
# 0           4.9          3.0           1.4          0.2  Iris-setosa
# 1           4.7          3.2           1.3          0.2  Iris-setosa
# 2           4.6          3.1           1.5          0.2  Iris-setosa
# 3           5.0          3.6           1.4          0.2  Iris-setosa
# 4           5.4          3.9           1.7          0.4  Iris-setosa

# %% [markdown]
# Check if any column has null values

# %%
iris.tail(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 137           6.7          3.1           5.6          2.4
# 138           6.9          3.1           5.1          2.3
# 139           5.8          2.7           5.1          1.9
# 140           6.8          3.2           5.9          2.3
# 141           6.7          3.3           5.7          2.5
# 142           6.7          3.0           5.2          2.3
# 143           6.3          2.5           5.0          1.9
# 144           6.5          3.0           5.2          2.0
# 145           6.2          3.4           5.4          2.3
# 146           5.9          3.0           5.1          1.8

# %%
print(iris.shape[0])
print(iris.shape[1])
# Out:
# 147
# 4

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# dtype: object

# %%
pd.isnull(iris).sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# class           0
# dtype: int64

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    147.000000   147.000000    147.000000   147.000000
# mean       5.864626     3.049660      3.740136     1.219048
# std        0.822192     0.436263      1.842187     0.757278
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.500000     0.300000
# 50%        5.800000     3.000000      4.400000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(round(iris.sepal_length.mean()))
# Out:
# 6

# %% [markdown]
# Set rows 10 to 29 of petal_length to NAN

# %%
iris.iloc[10:30, 2:3] = np.nan
iris.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           NaN          0.2  Iris-setosa
# 11           4.8          3.0           NaN          0.1  Iris-setosa
# ...

# %% [markdown]
# Fill the na cells with 1 (inplace)

# %%
iris.petal_length.fillna(1, inplace = True)
iris.head(20)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width        class
# 0            4.9          3.0           1.4          0.2  Iris-setosa
# 1            4.7          3.2           1.3          0.2  Iris-setosa
# 2            4.6          3.1           1.5          0.2  Iris-setosa
# 3            5.0          3.6           1.4          0.2  Iris-setosa
# 4            5.4          3.9           1.7          0.4  Iris-setosa
# 5            4.6          3.4           1.4          0.3  Iris-setosa
# 6            5.0          3.4           1.5          0.2  Iris-setosa
# 7            4.4          2.9           1.4          0.2  Iris-setosa
# 8            4.9          3.1           1.5          0.1  Iris-setosa
# 9            5.4          3.7           1.5          0.2  Iris-setosa
# 10           4.8          3.4           1.0          0.2  Iris-setosa
# 11           4.8          3.0           1.0          0.1  Iris-setosa
# ...

# %% [markdown]
# Take class column separately and drop it from the data

# %%
Y = iris['class']
Y
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
# 5         Iris-setosa
# 6         Iris-setosa
# 7         Iris-setosa
# 8         Iris-setosa
# 9         Iris-setosa
# 10        Iris-setosa
# 11        Iris-setosa
# 12        Iris-setosa
# 13        Iris-setosa
# 14        Iris-setosa
# 15        Iris-setosa
# 16        Iris-setosa
# 17        Iris-setosa
# 18        Iris-setosa
# 19        Iris-setosa
# 20        Iris-setosa
# 21        Iris-setosa
# 22        Iris-setosa
# 23        Iris-setosa
# 24        Iris-setosa
# 25        Iris-setosa
# 26        Iris-setosa
# 27        Iris-setosa
# 28        Iris-setosa
# 29        Iris-setosa
#             ...
# 119    Iris-virginica
# 120    Iris-virginica
# 121    Iris-virginica
# 122    Iris-virginica
# 123    Iris-virginica
# 124    Iris-virginica
# 125    Iris-virginica
# 126    Iris-virginica
# 127    Iris-virginica
# 128    Iris-virginica
# ...

# %%
del iris['class']
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.9          3.0           1.4          0.2
# 1           4.7          3.2           1.3          0.2
# 2           4.6          3.1           1.5          0.2
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4

# %% [markdown]
# (Give this as exercise) Set entire row 1 to 3 as NaN and then drop the same (using dropna)

# %%
iris.iloc[1:3, :] = np.nan
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             4.9          3.0           1.4          0.2
# 1             NaN          NaN           NaN          NaN
# 2             NaN          NaN           NaN          NaN
# 3             5.0          3.6           1.4          0.2
# 4             5.4          3.9           1.7          0.4
# 5             4.6          3.4           1.4          0.3
# 6             5.0          3.4           1.5          0.2
# 7             4.4          2.9           1.4          0.2
# 8             4.9          3.1           1.5          0.1
# 9             5.4          3.7           1.5          0.2
# 10            4.8          3.4           1.0          0.2
# 11            4.8          3.0           1.0          0.1
# 12            4.3          3.0           1.0          0.1
# 13            5.8          4.0           1.0          0.2
# 14            5.7          4.4           1.0          0.4
# ...

# %%
iris.dropna(inplace = True)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.9          3.0           1.4          0.2
# 3           5.0          3.6           1.4          0.2
# 4           5.4          3.9           1.7          0.4
# 5           4.6          3.4           1.4          0.3
# 6           5.0          3.4           1.5          0.2

# %% [markdown]
# Resetting index to start

# %%
iris.reset_index(drop = True, inplace = True)
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           4.9          3.0           1.4          0.2
# 1           5.0          3.6           1.4          0.2
# 2           5.4          3.9           1.7          0.4
# 3           4.6          3.4           1.4          0.3
# 4           5.0          3.4           1.5          0.2
